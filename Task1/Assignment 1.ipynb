# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model('https://ultralytics.com/images/bus.jpg')
# An online test image provided by Ultralytics.
results[0].show()
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 C:\Users\anees\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 109.0ms
# Speed: 4.9ms preprocess, 109.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)

# %%
path=r"C:\Users\anees\OneDrive\Pictures\Images\dog.jpeg"

# %%
from ultralytics import YOLO

model = YOLO('yolov8l.pt')
results = model(path)
results[0].show()
# Out:
# image 1/1 C:\Users\anees\OneDrive\Pictures\Images\dog.jpeg: 480x640 2 dogs, 655.9ms
# Speed: 2.6ms preprocess, 655.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
path1=r"C:\Users\anees\OneDrive\Pictures\Images\street.jpeg"
from ultralytics import YOLO

model = YOLO('yolov8l.pt')
results = model(path1)
results[0].show()
# Out:
# image 1/1 C:\Users\anees\OneDrive\Pictures\Images\street.jpeg: 384x640 14 persons, 1 car, 1 bus, 2 traffic lights, 1 handbag, 517.6ms
# Speed: 1.9ms preprocess, 517.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
path2=r"C:\Users\anees\OneDrive\Pictures\Images\high.jpeg"
from ultralytics import YOLO

model = YOLO('yolov8l.pt')
results = model(path2)
results[0].show()
# Out:
# image 1/1 C:\Users\anees\OneDrive\Pictures\Images\high.jpeg: 448x640 12 cars, 5 trucks, 687.4ms
# Speed: 3.0ms preprocess, 687.4ms inference, 3.8ms postprocess per image at shape (1, 3, 448, 640)
